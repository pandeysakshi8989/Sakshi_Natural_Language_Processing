# %%
# !pip install stanfordnlp
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting stanfordnlp
#   Downloading stanfordnlp-0.2.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: numpy in c:\users\saksh\appdata\roaming\python\python312\site-packages (from stanfordnlp) (2.2.4)
# Requirement already satisfied: protobuf in c:\users\saksh\appdata\roaming\python\python312\site-packages (from stanfordnlp) (3.20.3)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from stanfordnlp) (2.32.3)
# Requirement already satisfied: torch>=1.0.0 in c:\users\saksh\appdata\roaming\python\python312\site-packages (from stanfordnlp) (2.6.0)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from stanfordnlp) (4.66.5)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\lib\site-packages (from torch>=1.0.0->stanfordnlp) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\saksh\appdata\roaming\python\python312\site-packages (from torch>=1.0.0->stanfordnlp) (4.12.2)
# Requirement already satisfied: networkx in c:\programdata\anaconda3\lib\site-packages (from torch>=1.0.0->stanfordnlp) (3.3)
# Requirement already satisfied: jinja2 in c:\users\saksh\appdata\roaming\python\python312\site-packages (from torch>=1.0.0->stanfordnlp) (3.1.5)
# Requirement already satisfied: fsspec in c:\programdata\anaconda3\lib\site-packages (from torch>=1.0.0->stanfordnlp) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\saksh\appdata\roaming\python\python312\site-packages (from torch>=1.0.0->stanfordnlp) (75.8.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\saksh\appdata\roaming\python\python312\site-packages (from torch>=1.0.0->stanfordnlp) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\programdata\anaconda3\lib\site-packages (from sympy==1.13.1->torch>=1.0.0->stanfordnlp) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\saksh\appdata\roaming\python\python312\site-packages (from requests->stanfordnlp) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\saksh\appdata\roaming\python\python312\site-packages (from requests->stanfordnlp) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\saksh\appdata\roaming\python\python312\site-packages (from requests->stanfordnlp) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\saksh\appdata\roaming\python\python312\site-packages (from requests->stanfordnlp) (2025.1.31)
# Requirement already satisfied: colorama in c:\users\saksh\appdata\roaming\python\python312\site-packages (from tqdm->stanfordnlp) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\saksh\appdata\roaming\python\python312\site-packages (from jinja2->torch>=1.0.0->stanfordnlp) (3.0.2)
# Downloading stanfordnlp-0.2.0-py3-none-any.whl (158 kB)
# Installing collected packages: stanfordnlp
# Successfully installed stanfordnlp-0.2.0

# %%
import stanfordnlp
stanfordnlp.download('en')

from nltk.parse.corenlp import CoreNLPParser
from nltk.tokenize import word_tokenize

parser = CoreNLPParser(url='http://localhost:9000')
tokenizer = CoreNLPParser(url='http://localhost:9000', tagtype='pos')
pos_tagger = CoreNLPParser(url='http://localhost:9000', tagtype='pos')

sentence = "The quick brown fox jumps over the lazy dog."

tokens = word_tokenize(sentence)
print("Tokens:", tokens)

pos_tags = list(pos_tagger.tag(tokens))
print("POS Tags:", pos_tags)

parse_tree = next(parser.raw_parse(sentence))
print("Parse Tree:")
print(parse_tree)

parse_tree.pretty_print()
# Out:
# Using the default treebank "en_ewt" for language "en".
# Would you like to download the models for: en_ewt now? (Y/n)
